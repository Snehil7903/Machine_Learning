# %%
import pandas as pd

df = pd.read_csv("E:\\restart\\MachineLearning\\salary_prediction\\data\\salary.csv")

# %%
print(df.head())
# Out:
# Empty DataFrame
# Columns: [1, 1.1, 1.2, 1.3, 1.4]
# Index: []

# %%
print(df.shape)
# Out:
# (0, 5)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       0 non-null      object
#  1   1.1     0 non-null      object
#  2   1.2     0 non-null      object
#  3   1.3     0 non-null      object
#  4   1.4     0 non-null      object
# dtypes: object(5)
# memory usage: 132.0+ bytes
# None

# %%
print(df.describe())
# Out:
#           1  1.1  1.2  1.3  1.4
# count     0    0    0    0    0
# unique    0    0    0    0    0
# top     NaN  NaN  NaN  NaN  NaN
# freq    NaN  NaN  NaN  NaN  NaN

# %%
print(df.isnull().sum())

# %%
print(df.duplicated().sum())

# %%
print(df.columns)
# Out:
# Index(['1', '1.1', '1.2', '1.3', '1.4'], dtype='object')

# %%
pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.10.7)
# Requirement already satisfied: seaborn in c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(10,8))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 df.hist(figsize=(10,8))
#       5 plt.show()
#
# File c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_core.py:251, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     164 """
#     165 Make a histogram of the DataFrame's columns.
#     166
#    (...)    248     >>> hist = df.hist(bins=3)
#     249 """
#     250 plot_backend = _get_plot_backend(backend)
# --> 251 return plot_backend.hist_frame(
#     252     data,
#     253     column=column,
#     254     by=by,
#     255     grid=grid,
#     256     xlabelsize=xlabelsize,
#     257     xrot=xrot,
#     258     ylabelsize=ylabelsize,
#     259     yrot=yrot,
#     260     ax=ax,
#     261     sharex=sharex,
#     262     sharey=sharey,
#     263     figsize=figsize,
#     264     layout=layout,
#     265     legend=legend,
#     266     bins=bins,
#     267     **kwargs,
#     268 )
#
# File c:\Users\snehi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_matplotlib\hist.py:549, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     546 naxes = len(data.columns)
#     548 if naxes == 0:
# --> 549     raise ValueError(
#     550         "hist method requires numerical or datetime columns, nothing to plot."
#     551     )
#     553 fig, axes = create_subplots(
#     554     naxes=naxes,
#     555     ax=ax,
#    (...)    560     layout=layout,
#     561 )
#     562 _axes = flatten_axes(axes)
#
# ValueError: hist method requires numerical or datetime columns, nothing to plot.

# %%
print(df.corr(numeric_only=True))

# %%
plt.scatter(
    df["Experience"],
    df["Salary"]
)

plt.xlabel("Experience")
plt.ylabel("Salary")

plt.show()
